# %%
import pickle
import numpy as np

# %%
file_name = "AntController/configs/fixed_frame_data.p"
infile = open(file_name,'rb')
data = pickle.load(infile)

# %%
data
# Out:
# {'actor_loss': [array(-248.32863, dtype=float32),
#   array(214.64319, dtype=float32),
#   array(177.1499, dtype=float32),
#   array(111.57115, dtype=float32),
#   array(-224.72214, dtype=float32),
#   array(140.77838, dtype=float32),
#   array(348.72775, dtype=float32),
#   array(-34.637413, dtype=float32),
#   array(241.65887, dtype=float32),
#   array(-68.988144, dtype=float32),
#   array(-115.99306, dtype=float32),
#   array(169.04211, dtype=float32),
#   array(-125.105644, dtype=float32),
#   array(384.7953, dtype=float32),
#   array(134.71182, dtype=float32),
#   array(266.66895, dtype=float32),
#   array(113.45998, dtype=float32),
#   array(-53.23472, dtype=float32),
#   array(183.06035, dtype=float32),
#   array(275.18427, dtype=float32),
#   array(435.95657, dtype=float32),
#   array(340.8452, dtype=float32),
#   array(128.9436, dtype=float32),
#   array(-61.94818, dtype=float32),
#   array(164.59866, dtype=float32),
#   array(207.15784, dtype=float32),
# ...

# %%
np.asarray(data["actor_loss"])/64
# Out:
# array([-3.8801348 ,  3.3537998 ,  2.7679672 ,  1.7432992 , -3.5112834 ,
#         2.1996622 ,  5.448871  , -0.5412096 ,  3.77592   , -1.0779397 ,
#        -1.8123915 ,  2.641283  , -1.9547757 ,  6.0124264 ,  2.1048722 ,
#         4.1667023 ,  1.7728121 , -0.8317925 ,  2.860318  ,  4.299754  ,
#         6.8118215 ,  5.3257065 ,  2.0147438 , -0.96794033,  2.571854  ,
#         3.2368412 , -0.07828015,  4.468342  ,  2.8923738 ,  3.2685966 ,
#         3.66296   ,  4.6323156 ,  0.2715065 ,  2.121922  ,  4.633319  ,
#         6.571378  ,  0.09141651,  2.6055186 ,  2.747571  ,  3.0293484 ,
#        -0.12194064,  1.3222226 , -0.4485922 ,  2.8437738 ,  1.2778214 ,
#         3.4020681 ,  0.43275106,  4.8096647 ,  3.7308538 ,  8.521296  ,
#         6.068477  ,  4.255704  ,  4.9636908 ,  7.556072  ,  5.003048  ,
#         0.22749302,  1.5843246 ,  7.5771    ,  2.0632787 ,  8.74338   ,
#         1.9530379 ,  6.4405026 ,  5.8086233 ,  5.493272  ,  5.039419  ,
# ...

# %%
np.asarray(data["critic_loss"])/64
# Out:
# array([ 7.0884323,  4.0598903,  5.997793 ,  6.3733835,  6.0417   ,
#         3.1872725,  5.4762673,  3.8497815,  3.8164682,  3.4902287,
#         3.7256217,  6.709284 ,  4.3474493,  5.3165016,  4.5130525,
#         4.9276757,  6.047617 ,  4.565062 ,  4.5873384,  6.5371013,
#         5.0931673,  3.6806355,  7.8289747,  5.8633204,  5.2686434,
#         6.330826 ,  3.3867514,  6.6349707,  3.9503016,  4.195006 ,
#         6.2547903,  4.4718056,  4.0907135,  4.250737 ,  5.039645 ,
#         8.927162 ,  7.3013554,  4.705473 ,  4.2624307,  4.7141533,
#         4.811326 ,  5.2578278,  4.6670003,  4.6494694,  3.788263 ,
#         5.861925 ,  2.7469487,  4.5223446,  3.7638464,  4.34878  ,
#         5.1827154,  4.2085238,  3.4512582,  6.565036 ,  4.5291967,
#         3.253687 ,  3.8608155,  5.7302494,  3.2386327,  6.4738636,
#         3.9605384,  5.4233136,  3.5784245,  5.933282 ,  4.5559864,
#         4.4926834,  6.65557  ,  3.4731088,  4.4023476,  5.6423097,
# ...

# %%
[data["episode_length"][i] for i in range(len(data["episode_length"])) if data['success'][i]]
# Out:
# [91,
#  97,
#  91,
#  66,
#  51,
#  51,
#  47,
#  56,
#  56,
#  57,
#  59,
#  60,
#  60,
#  60,
#  62,
#  57,
#  65,
#  61,
#  56,
#  69,
#  56,
#  55,
#  51,
#  60,
#  55,
#  55,
#  40,
#  51,
#  47,
#  41,
#  45,
#  42,
#  46,
#  41,
#  40,
#  45,
#  45,
#  46,
#  45,
#  46,
#  40,
#  50,
#  49,
#  45,
#  45,
#  39,
#  40,
#  39,
#  40,
#  45,
#  38,
#  35,
#  47,
#  44,
#  29,
#  35,
#  29,
#  29,
#  29,
#  28,
#  30,
#  34,
#  31,
#  31,
#  30,
#  29,
#  31,
#  26,
#  28,
#  30,
#  35,
#  35]
